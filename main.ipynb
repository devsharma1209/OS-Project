# %%
import nbimporter

# %%
from algorithms import fcfs, sjf, round_robin, priority_scheduling
from linux_fetch import fetch_linux_processes
from utils import print_table
from gantt import plot_gantt

# %%
# processes = [
#     {"pid": 1, "arrival": 0, "burst": 5, "priority": 2},
#     {"pid": 2, "arrival": 1, "burst": 3, "priority": 1},
#     {"pid": 3, "arrival": 2, "burst": 8, "priority": 3},
#     {"pid": 4, "arrival": 3, "burst": 6, "priority": 2},
#     {"pid": 5, "arrival": 5, "burst": 7, "priority": 1},
#     {"pid": 6, "arrival": 7, "burst": 12, "priority": 3}
# ]

# %%
def main():
    print("Fetching Linux processes...")
    processes = fetch_linux_processes(top_n=5)
    for p in processes:
        print(p)
    
    print("\nRunning FCFS Scheduler...")
    fcfs_results = fcfs(processes)
    print_table(fcfs_results)
    plot_gantt(fcfs_results, "FCFS Gantt Chart")

    print("\nRunning SJF Scheduler...")
    sjf_results = sjf(processes)
    print_table(sjf_results)
    plot_gantt(sjf_results, "SJF Gantt Chart")

    print("\nRunning Round Robin Scheduler...")
    rr_results = round_robin(processes, quantum=2)
    print_table(rr_results)
    plot_gantt(rr_results, "Round Robin Gantt Chart")

    print("\nRunning Priority Scheduling...")
    prio_results = priority_scheduling(processes)
    print_table(prio_results)
    plot_gantt(prio_results, "Priority Scheduling Gantt Chart")

if __name__ == "__main__":
    main()
# Out:
# Fetching Linux processes...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 28
#      25     plot_gantt(prio_results, "Priority Scheduling Gantt Chart")
#      27 if __name__ == "__main__":
# ---> 28     main()
#
# Cell In[32], line 3, in main()
#       1 def main():
#       2     print("Fetching Linux processes...")
# ----> 3     processes = fetch_linux_processes(top_n=5)
#       4     for p in processes:
#       5         print(p)
#
# File c:\Users\Dev Sharma\Desktop\UNI WORK\Python\OS Project\ProcessScheduler\linux_fetch.ipynb:12, in fetch_linux_processes(top_n)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "dac2abeb",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import subprocess"
#      11    ]
# ---> 12   },
#      13   {
#      14    "cell_type": "code",
#      15    "execution_count": 2,
#      16    "id": "2efe1d7c",
#      17    "metadata": {},
#      18    "outputs": [],
#      19    "source": [
#      20     "def fetch_linux_processes(top_n=5):\n",
#      21     "    \"\"\"\n",
#      22     "    Fetch top N processes by CPU priority.\n",
#      23     "    Returns a list of dicts: pid, priority, elapsed_time\n",
#      24     "    \"\"\"\n",
#      25     "    cmd = f\"ps -eo pid,comm,pri,etimes --sort=-pri | head -n {top_n+1}\"\n",
#      26     "    output = subprocess.getoutput(cmd).splitlines()[1:]  # skip header\n",
#      27     "    processes = []\n",
#      28     "    for line in output:\n",
#      29     "        parts = line.split()\n",
#      30     "        processes.append({\n",
#      31     "            \"pid\": int(parts[0]),\n",
#      32     "            \"name\": parts[1],\n",
#      33     "            \"priority\": int(parts[2]),\n",
#      34     "            \"burst\": int(parts[3]),  # approximate using elapsed time\n",
#      35     "            \"arrival\": 0\n",
#      36     "        })\n",
#      37     "    return processes"
#      38    ]
#      39   },
#      40   {
#      41    "cell_type": "code",
#      42    "execution_count": null,
#      43    "id": "7c99caad",
#      44    "metadata": {},
#      45    "outputs": [],
#      46    "source": []
#      47   }
#      48  ],
#      49  "metadata": {
#      50   "kernelspec": {
#      51    "display_name": "Python 3",
#      52    "language": "python",
#      53    "name": "python3"
#      54   },
#      55   "language_info": {
#      56    "codemirror_mode": {
#      57     "name": "ipython",
#      58     "version": 3
#      59    },
#      60    "file_extension": ".py",
#      61    "mimetype": "text/x-python",
#      62    "name": "python",
#      63    "nbconvert_exporter": "python",
#      64    "pygments_lexer": "ipython3",
#      65    "version": "3.11.6"
#      66   }
#      67  },
#      68  "nbformat": 4,
#      69  "nbformat_minor": 5
#      70 }
#
# ValueError: invalid literal for int() with base 10: 'operable'
